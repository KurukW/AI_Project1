# %% [markdown]
# # Modele de réseau neuronale

# %% [markdown]
# 19/4/21 11:20
# Un nouveau modele est pret à être train

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
#import seaborn as sns #On ne sait jamais que ça serve
import pandas as pd 
from sklearn.preprocessing import MinMaxScaler #Normalisation #Il faut l'installer aussi avec conda install
import random
from math import ceil


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Sequential
from tensorflow.keras.layers import  Dense, Conv3D, BatchNormalization,MaxPooling3D, Dropout, LSTM, ConvLSTM2D
from tensorflow.keras.utils import to_categorical


#conda install pydot
#conda install pydotplus
#conda install graphviz
from tensorflow.keras.utils import plot_model
#import pydot

#Afin que keras ne réinitialise pas les poids quand on enregistre le modèle
from tensorflow.keras.backend import manual_variable_initialization 
manual_variable_initialization(True)

import threading
from queue import Queue, Empty
from time import sleep, time

# %% [markdown]
# ### Paramètres généraux

# %%
fps = 10
size = (120,90) #(40,30)
nb_classes = 10 #Nombre de classes
epochs = 3
batch_size = 20
pack_size = 40
learning_rate = 0.002
modele_n = "12"

# %% [markdown]
# ## Fonctions d'imports et preprocess

# %% [markdown]
# #### Import

# %%
def get_mov_imgs_from_path(path,fps = -1,color = 'gray'):
    '''
    Retourne une liste d'images pour une vidéo. La liste d'image a le nombre de fps voulu
    reprend que le mouvement
    '''
    
    cap = cv2.VideoCapture(path)
    try:
        fps_actu = cap.get(cv2.CAP_PROP_FPS)
    #     print(f"Traitement de la video n° {path}       ",end="\r")
        if fps <= -1: fps = fps_actu #Je peux ne pas donner de fps et ça va prendre le nombre d'fps initial
        ecart_voulu = int(1000/fps)
        ecart_initial = int(1000/fps_actu)
        imgs = []

        ret, frame = cap.read()
        while(cap.isOpened()):
            prev = frame
            ret, frame = cap.read()



            if ret: #Sinon ça plante quand il n'y a plus d'images
                #Récupère seulement certaines images
                t_ms = cap.get(cv2.CAP_PROP_POS_MSEC)
                modulo = t_ms % ecart_voulu
                if modulo < ecart_initial:
                    #Isoler les images

                    if color == 'gray':
                        gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
                        prev_gray = cv2.cvtColor(prev,cv2.COLOR_BGR2GRAY)
                        diff_gray = cv2.absdiff(gray,prev_gray)

                    elif color == 'rgb':
                        diff_gray = cv2.absdiff(frame,prev) 

                    #On va travailler avec des images en nuance de gris, c'est bcp plus simple
                    imgs.append(diff_gray)

            else: #Va jusqu'au bout de la vidéo
                break
        else:
            print("Le fichier n'a pas pu être ouvert")
    except:
        print(f"IL Y A UN PROBLEME AVEC LA VIDEO: {path}")
        return None
    cap.release()
    
    return imgs

# %% [markdown]
# #### Resize

# %%
def resize_imgs(imgs,nsize):
    '''
    Change la taille de l'image.
    Le premier élément de nsize est la longueur (width), le deuxième la hauteur (height)
    '''
    return [cv2.resize(img, dsize=nsize, interpolation=cv2.INTER_LINEAR) for img in imgs]

# %% [markdown]
# #### Normalisation

# %%
def normalize_imgs(imgs):
    '''
    Normalise une série d'images
    On divise par le max de l'image parce que certains bons modèles ont été entrainé comme cela
    '''
    liste = []
    for img in imgs:
        max_ = float(img.max())
        if max_ != 0:
            liste.append(img/max_)
        else:
            liste.append(img)
    return liste

# %% [markdown]
# ## Fonction de générateur

# %%
def my_gen(labels_list, folder_path, pack_size = 10, pointer = 0, fps = 5, size = (160,120)):
    '''
    à partir de la liste des labels et de la position du foler
    Retourne:
    -une liste d'images de vidéos de shape (pack_size,n_frames,height,width[,channels])
        n_frames = fps*2.4
    -Une liste de numérique avec les labels correspondant aux images (de len = batch_size)
    -Un pointer qui permet de faire tourner my_gen à nouveau et recevoir les éléments suivants de la liste
    
    
    Normalement on peut envoyer X et y_num dans le modele directement (avec fit ou train_on_batch, les deux devraient fonctionner)
    Je vais essayer de travailler avec des thread pour avoir un thread en Train et un trhead en gen
    '''
    #Affiche combien de paquets il faudra
    len_label = len(labels_list)
    if pointer == 0:
        #Uniquement le premier passage
        nb_pack = ceil(len_label/pack_size)
        print(f"Il y aura {nb_pack} packs de {min(pack_size,len_label)} vidéos à importer")
    else:
        print(f"Il reste encore {len_label - pointer} vidéos à importer")
    
    videos = []
    y_num = []
    X = []
    for i in range(pointer, pack_size + pointer):
        pointer = i+1
        if i >= len_label:
            break
        label, video_name = labels_list[i]
        
        #Label en numérique
        y_num.append(labels_n[label])
        
        #Preprocess d'images
        file_path = folder_path + "\\" + video_name
        imgs_of_video = get_mov_imgs_from_path(file_path,fps,'gray') #Gray ou rgb
        if imgs_of_video == None:
            continue
        resized_imgs = resize_imgs(imgs_of_video, size)
        norm_imgs = normalize_imgs(resized_imgs)
        
        videos.append(imgs_of_video)
        X.append(norm_imgs)
        
    print() #Pour ne pas écrire sur la même ligne qu'avant
    X = np.array(X)
    y = np.array(y_num)
    videos = np.array(videos)
    
    #Ajouter une dimsension en à la fin est nécessaire pour certains modèle
    #Commenter cette ligne si ce n'est pas nécessaire
    X = np.expand_dims(X, axis=len(X.shape)) 
    
    # Si le modele est compile avec :loss='sparse_categorical_crossentropy'
    # Il faut un y catégorique , faire ça hors de la fonction
    #y = to_categorical(y, num_classes = nb_classes)

    return (X, y, pointer, videos)

# %% [markdown]
# ## Import des données et traitement

# %%
#Import des labels
labels_csv = pd.read_csv("DATA\\labels.csv")
labels_name = pd.read_csv("DATA\\labels_uses.csv")
labels_tests_csv = pd.read_csv("DATA\\labels_tests.csv")

# %%
#Créé un dictionnaire qui associe le nom du label et un numérique afin de le mettre dans le modele
labels_n = {}
for i,label in enumerate(labels_name.values):
    labels_n[label[0]] = i
    labels_n[i] = label[0]

    
#Trier les labels pour ne prendre que ceux qui correspondent à labels_uses
labels = []
for label, video_name in labels_csv.values:
    if label in labels_n:
        labels.append((label,video_name))

#Idem pour le label de tests
labels_tests = []
for label, video_name in labels_tests_csv.values:
    if label in labels_n:
        labels_tests.append((label,video_name))


#Melange la liste de train
for j in range(5):
    random.shuffle(labels) #Il faut absolument shuffle pour train

# %%
#Count de chaque label
labels_c = {}
for label in labels_name.values:
    labels_c[label[0]] = 0

for label,video_name in labels:
    if label in labels_c:
        labels_c[label] += 1

print(labels_c)
# Out:
# {'Ferme le poing': 142, 'Ouvre le poing': 142, 'Clap': 143, 'Swipe gauche main droite': 142, 'Swipe droit main gauche': 142, 'Doigts croises paumes': 142, 'Explosion avec les doigts ouverts': 142, 'Ouvrir un livre avec le poing ferme main D': 142, 'Ouvrir un livre avec le poing ferme main G': 142, 'Faire coucou': 142}

# %% [markdown]
# ## Import model

# %%
model_saved = keras.models.load_model("Saved_model\\model_12_90_120_acc83.h5")

# %% [markdown]
# ## Tests

# %%
X_test, y_test, _ = my_gen(labels_tests, "DATA\\V_tests",pack_size = 1000,fps = fps, size = size)
#Grand pack_size afin de prendre toutes les données
# Out:
# Il y aura 1 packs de 131 vidéos à importer

# %%
with tf.device('cpu:0'):
    start_pred = time()
    y_pred = model.predict(X_test)
    end_pred = time()
    print(f"La prédiction prend {end_pred - start_pred} secondes")
# Out:
# La prédiction prend 346.3881130218506 secondes

# %% [markdown]
# ## Affichage d'une video avec la prédiction pour comprendre si le résultat est justifié ou non

# %%
plt.figure(figsize=(20,60)) #(20,60) pour des images en (120,160). (20,180) pour des images en (480,640)
#print(X_test.shape)
#Visu des mouvements avec une petite size (en fonction des paramètres initiaux)
columns = 3
vid_a_test = 3
print("original:",labels_n[y_test[vid_a_test]])
print("prediction:",labels_n[y_pred[vid_a_test].argmax()])
for i, img in enumerate(X_test[vid_a_test]):
    plt.subplot(int(len(img) / columns + 1), columns, i + 1)
    plt.imshow(img)
# Out:
# original: Ouvre le poing
# prediction: Ferme le poing

# %% [markdown]
# ### visualisation des  résultats

# %%
import fidle.pwk as pwk

# %%
y_pred_arg = np.argmax(y_pred, axis=-1)
#plot_confusion_name = full_name + '_confusion.png'
cfm_plot = pwk.plot_confusion_matrix(y_test,y_pred_arg,range(nb_classes),normalize=True)

# %%
with tf.device('cpu:0'):
    y_test_cat = to_categorical(y_test,10)
    score = model.evaluate(X_test, y_test_cat, verbose=1)

print('Test loss     :', score[0])
print('Test accuracy :', score[1])

# %%
#y_pred

# %%
print(labels_n)
# Out:
# {'Ferme le poing': 0, 0: 'Ferme le poing', 'Ouvre le poing': 1, 1: 'Ouvre le poing', 'Clap': 2, 2: 'Clap', 'Swipe gauche main droite': 3, 3: 'Swipe gauche main droite', 'Swipe droit main gauche': 4, 4: 'Swipe droit main gauche', 'Doigts croises paumes': 5, 5: 'Doigts croises paumes', 'Explosion avec les doigts ouverts': 6, 6: 'Explosion avec les doigts ouverts', 'Ouvrir un livre avec le poing ferme main D': 7, 7: 'Ouvrir un livre avec le poing ferme main D', 'Ouvrir un livre avec le poing ferme main G': 8, 8: 'Ouvrir un livre avec le poing ferme main G', 'Faire coucou': 9, 9: 'Faire coucou'}

# %%
#Je peux afficher l'historique de chaque étape (je n'ai aps réussi à les faire fusionner)
#On ne peut afficher que si on a train

#history = histories[-1]
#pwk.plot_history(history, figsize=(6,4), save_as='03-history')

# %%
#Compte le nombre de bons et de mauvais qu'on a ainsi que la moyenne,
curseur  = 0.6 #curseur de 0 pour avoir tous les résultats
count_good = 0
to_mean_good = 0
count_bad = 0
to_mean_bad = 0
for i,pred in enumerate(y_pred):
    #Curseur
    if np.max(pred) < curseur:
        continue
    if np.argmax(pred) == y_test[i]:
        count_good += 1
        to_mean_good += max(pred)
    else:
        count_bad +=1
        to_mean_bad += max(pred)
if count_good != 0:
    mean_good = to_mean_good/count_good
else: mean_good = 0
if count_bad != 0:
    mean_bad = to_mean_bad /count_bad
else: mean_bad = 0
print("Nombre de bon :", count_good," Moyenne :",mean_good)
print("Nombre de mauvais :",count_bad, " Moyenne :",mean_bad)
#On constate que le modèle est souvent très sûr de ce qu'il avance
# Out:
# Nombre de bon : 84  Moyenne : 0.9058684358994166
# Nombre de mauvais : 3  Moyenne : 0.6296066045761108

# %%
model_saved.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d (Conv3D)              (None, 24, 90, 120, 256)  32256
# _________________________________________________________________
# dense (Dense)                (None, 24, 90, 120, 256)  65792
# _________________________________________________________________
# dropout (Dropout)            (None, 24, 90, 120, 256)  0
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 24, 30, 40, 85)    0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 24, 30, 40, 85)    340
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 30, 40, 85)    0
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 24, 30, 40, 64)    146944
# _________________________________________________________________
# dense_1 (Dense)              (None, 24, 30, 40, 64)    4160
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 24, 15, 20, 64)    0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 24, 15, 20, 64)    256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 24, 15, 20, 64)    0
# _________________________________________________________________
# conv_lst_m2d (ConvLSTM2D)    (None, 24, 11, 16, 64)    819456
# _________________________________________________________________
# conv_lst_m2d_1 (ConvLSTM2D)  (None, 24, 9, 14, 64)     295168
# _________________________________________________________________
# reshape (Reshape)            (None, 24, 8064)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 64)                2081024
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 3,446,046
# Trainable params: 3,445,748
# Non-trainable params: 298
# _________________________________________________________________

# %%
from tensorflow.keras.models import Model
models = []
for i in range(13):
    if i == 0:
        continue
    
    model_layer = Model(inputs=model_saved.input, outputs=model_saved.layers[i].output)
    
    models.append(model_layer)
#-8 pour avoir le dernier max_poooling

# %%
model = models[-1]

# %%
model.summary()
# Out:
# Model: "functional_319"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_input (InputLayer)    [(None, 24, 90, 120, 1)]  0
# _________________________________________________________________
# conv3d (Conv3D)              (None, 24, 90, 120, 256)  32256
# _________________________________________________________________
# dense (Dense)                (None, 24, 90, 120, 256)  65792
# _________________________________________________________________
# dropout (Dropout)            (None, 24, 90, 120, 256)  0
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 24, 30, 40, 85)    0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 24, 30, 40, 85)    340
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 30, 40, 85)    0
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 24, 30, 40, 64)    146944
# _________________________________________________________________
# dense_1 (Dense)              (None, 24, 30, 40, 64)    4160
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 24, 15, 20, 64)    0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 24, 15, 20, 64)    256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 24, 15, 20, 64)    0
# _________________________________________________________________
# conv_lst_m2d (ConvLSTM2D)    (None, 24, 11, 16, 64)    819456
# _________________________________________________________________
# conv_lst_m2d_1 (ConvLSTM2D)  (None, 24, 9, 14, 64)     295168
# =================================================================
# Total params: 1,364,372
# Trainable params: 1,364,074
# Non-trainable params: 298
# _________________________________________________________________

# %%
# Out:
# conv3d

# %%
X_test, y_test, _, real_imgs = my_gen(labels_tests, "DATA\\V_tests",pack_size = 2,fps = fps, size = size,pointer = 100)
# Out:
# Il reste encore 31 vidéos à importer

# %%
#Je dois prédire à chaque fois pour chaque model pour obtenir la sortie de chaque bout de model 
steps = []
for model in models:
    out = model.predict(X_test)
    out_np = np.array(out)
    steps.append(out_np)
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000234D1A44F70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000234D1A44820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000234E50E9670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000234E50E98B0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000234E85BB160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000234E65C0820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000234E85BB670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000234E67874C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000234D1A2EAF0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000234E62F2820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000234E6546310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000234E6624940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
for i,s in enumerate(steps):
    print(steps[i].shape)
# Out:
# (2, 24, 90, 120, 256)
# (2, 24, 90, 120, 256)
# (2, 24, 30, 40, 85)
# (2, 24, 30, 40, 85)
# (2, 24, 30, 40, 85)
# (2, 24, 30, 40, 64)
# (2, 24, 30, 40, 64)
# (2, 24, 15, 20, 64)
# (2, 24, 15, 20, 64)
# (2, 24, 15, 20, 64)
# (2, 24, 11, 16, 64)
# (2, 24, 9, 14, 64)

# %%
# n_video = 0 #Parce que je ne prend que deux éléments, le numéro de la vidéo se choisit au niveau du pointer
# n_frame = 13
# n_kernel = 0

# print(out_np.shape)
# img = out_np[n_video]
# print(img.shape)
# frame = out_np[n_video][n_frame]
# print(frame.shape)
# img = out_np[n_video][n_frame][:]
# print(img.shape)
# img = out_np[n_video][n_frame][:][:]
# print(img.shape)
# img = out_np[n_video][n_frame][:][:][n_kernel]
# print(img.shape)
# #Il y a un probleme, je n'ai pas récupéré le bon format, solution à la cellule en dessous

# %%
#Récupère trois images par couche
imgs_steps = []
for out in steps:
    imgs = []
    frame = out[0][13] #Numéro de la frame
    for i in range(3):
        img1 = []
        for line in frame:
            lin = []
            for pixel in line:
                lin.append(pixel[i])
            img1.append(lin)
        imgs.append(img1)
    imgs_steps.append(imgs)

# %%
#Récupère chaque kernel d'une couche
# imgs = []
# for i in range(64):
#     img1 = []
#     for line in frame:
#         lin = []
#         for pixel in line:
#             lin.append(pixel[i])
#         img1.append(lin)
#     imgs.append(img1)
# print(np.array(imgs).shape)

# %%
#Image réelle
plt.imshow(real_imgs[n_video][n_frame])

# %%
#Image envoyée au modèle
print(labels_n[y_test[n_video]])
plt.imshow(X_test[n_video][n_frame])
# Out:
# Doigts croises paumes

# %%
#Les kernels qui en sortent
# plt.figure(figsize=(20,20))
# for i, img in enumerate(imgs):
#     if i >= 5*5:
#         break
#     plt.subplot(5,5,i+1)
#     plt.imshow(img)
len(imgs_steps)
# Out:
# 12

# %%
#Affichage des trois images de chaque couche
plt.figure(figsize=(20,50))
for j,imgs in enumerate(imgs_steps):
    #plt.title(model.layers[j+1].name) #pas sûr du nom indiqué
    for i, img in enumerate(imgs):
        plt.subplot(15,3,j*3+i+1)
        plt.imshow(img)
